# %%
from datasets import load_dataset
dataset=load_dataset("go_emotions","simplified")

print (dataset)
# Out:
# README.md:   0%|          | 0.00/9.40k [00:00<?, ?B/s]
# E:\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Pratham Rajput\.cache\huggingface\hub\datasets--go_emotions. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ---------------------------------------------------------------------------
# HfUriError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datasets import load_dataset
# ----> 2 dataset=load_dataset("go_emotions","simplified")
#       4 print (dataset)
#
# File E:\anaconda3\Lib\site-packages\datasets\load.py:1698, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1693 verification_mode = VerificationMode(
#    1694     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1695 )
#    1697 # Create a dataset builder
# -> 1698 builder_instance = load_dataset_builder(
#    1699     path=path,
#    1700     name=name,
#    1701     data_dir=data_dir,
#    1702     data_files=data_files,
#    1703     cache_dir=cache_dir,
#    1704     features=features,
#    1705     download_config=download_config,
#    1706     download_mode=download_mode,
#    1707     revision=revision,
#    1708     token=token,
#    1709     storage_options=storage_options,
#    1710     **config_kwargs,
#    1711 )
#    1713 # Return iterable dataset in case of streaming
#    1714 if streaming:
#
# File E:\anaconda3\Lib\site-packages\datasets\load.py:1325, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1323 if features is not None:
#    1324     features = _fix_for_backward_compatible_features(features)
# -> 1325 dataset_module = dataset_module_factory(
#    1326     path,
#    1327     revision=revision,
#    1328     download_config=download_config,
#    1329     download_mode=download_mode,
#    1330     data_dir=data_dir,
#    1331     data_files=data_files,
#    1332     cache_dir=cache_dir,
#    1333 )
#    1334 # Get dataset builder class
#    1335 builder_kwargs = dataset_module.builder_kwargs
#
# File E:\anaconda3\Lib\site-packages\datasets\load.py:1217, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1212             if isinstance(e1, FileNotFoundError):
#    1213                 raise FileNotFoundError(
#    1214                     f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1215                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1216                 ) from None
# -> 1217             raise e1 from None
#    1218 else:
#    1219     raise FileNotFoundError(f"Couldn't find any data file at {relative_to_absolute_path(path)}.")
#
# File E:\anaconda3\Lib\site-packages\datasets\load.py:1192, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1182     else:
#    1183         use_exported_dataset_infos = True
#    1184     return HubDatasetModuleFactory(
#    1185         path,
#    1186         commit_hash=commit_hash,
#    1187         data_dir=data_dir,
#    1188         data_files=data_files,
#    1189         download_config=download_config,
#    1190         download_mode=download_mode,
#    1191         use_exported_dataset_infos=use_exported_dataset_infos,
# -> 1192     ).get_module()
#    1193 except GatedRepoError as e:
#    1194     message = f"Dataset '{path}' is a gated dataset on the Hub."
#
# File E:\anaconda3\Lib\site-packages\datasets\load.py:608, in HubDatasetModuleFactory.get_module(self)
#     606     download_config.download_desc = "Downloading standalone yaml"
#     607 try:
# --> 608     standalone_yaml_path = cached_path(
#     609         hf_dataset_url(self.name, config.REPOYAML_FILENAME, revision=self.commit_hash),
#     610         download_config=download_config,
#     611     )
#     612     with open(standalone_yaml_path, encoding="utf-8") as f:
#     613         standalone_yaml_data = yaml.safe_load(f.read())
#
# File E:\anaconda3\Lib\site-packages\datasets\utils\file_utils.py:180, in cached_path(url_or_filename, download_config, **download_kwargs)
#     174 # Download files from Hugging Face.
#     175 # Note: no need to check for https://huggingface.co file URLs since _prepare_path_and_storage_options
#     176 # prepares Hugging Face HTTP URLs as hf:// paths already
#     177 if url_or_filename.startswith("hf://") and not url_or_filename.startswith("hf://buckets/"):
#     178     resolved_path = huggingface_hub.HfFileSystem(
#     179         endpoint=config.HF_ENDPOINT, token=download_config.token
# --> 180     ).resolve_path(url_or_filename)
#     181     try:
#     182         output_path = huggingface_hub.HfApi(
#     183             endpoint=config.HF_ENDPOINT,
#     184             token=download_config.token,
#    (...)    194             proxies=download_config.proxies,
#     195         )
#
# File E:\anaconda3\Lib\site-packages\huggingface_hub\hf_file_system.py:305, in HfFileSystem.resolve_path(self, path, revision)
#     300 if path.count("/") == 0:
#     301     raise ValueError(
#     302         f"Repository id must be 'namespace/name', got '{path}'. Single-segment ids (e.g. 'gpt2') are no longer supported."
#     303     )
# --> 305 parsed = parse_hf_uri(f"{constants.HF_PROTOCOL}{path}")
#     307 # --- Buckets ---
#     308 if parsed.is_bucket:
#
# File E:\anaconda3\Lib\site-packages\huggingface_hub\utils\_hf_uris.py:313, in parse_hf_uri(uri)
#     311 if type_ == "bucket":
#     312     return _parse_bucket_body(location, type_, raw=raw)
# --> 313 return _parse_repo_body(location, type_, raw=raw)
#
# File E:\anaconda3\Lib\site-packages\huggingface_hub\utils\_hf_uris.py:582, in _parse_repo_body(location, type_, raw)
#     580     raise HfUriError(uri=raw, msg="Missing repository id before '@'.")
#     581 if repo_id.count("/") != 1:
# --> 582     raise HfUriError(uri=raw, msg=f"Repository id must be 'namespace/name', got '{repo_id}'.")
#     583 # Special refs like 'refs/pr/10' contain '/' and must be matched eagerly,
#     584 # otherwise we would split them at the first '/' and treat the rest as a path.
#     585 match = _SPECIAL_REFS_REVISION_REGEX.match(rev_and_path)
#
# HfUriError: Invalid HF URI 'hf://datasets/go_emotions@add492243ff905527e67aeb8b80c082af02207c3/.huggingface.yaml'. Repository id must be 'namespace/name', got 'go_emotions'.

# %%
import datasets
import huggingface_hub

print("datasets:", datasets.__version__)
print("huggingface_hub:", huggingface_hub.__version__)
# Out:
# datasets: 5.0.0
# huggingface_hub: 1.18.0

# %%
from datasets import load_dataset

dataset = load_dataset(
    "google-research-datasets/go_emotions",
    "simplified",
    trust_remote_code=True
)

print(dataset)
# Out:
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'google-research-datasets/go_emotions' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# README.md:   0%|          | 0.00/9.40k [00:00<?, ?B/s]
# E:\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Pratham Rajput\.cache\huggingface\hub\datasets--google-research-datasets--go_emotions. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# simplified/train-00000-of-00001.parquet:   0%|          | 0.00/2.77M [00:00<?, ?B/s]
# simplified/validation-00000-of-00001.par(…):   0%|          | 0.00/350k [00:00<?, ?B/s]
# simplified/test-00000-of-00001.parquet:   0%|          | 0.00/347k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/43410 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5426 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5427 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 43410
#     })
#     validation: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5426
#     })
#     test: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5427
#     })
# })

# %%
import sys
print(sys.version)

import datasets
print(datasets.__version__)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# 5.0.0

# %%
print(dataset["train"][0])
# Out:
# {'text': "My favourite food is anything I didn't have to cook myself.", 'labels': [27], 'id': 'eebbqej'}

# %%
print(dataset['train'][0])
# Out:
# {'text': "My favourite food is anything I didn't have to cook myself.", 'labels': [27], 'id': 'eebbqej'}

# %%
for i in range (5):
    example=dataset['train'][i]
    print(f"Text : {example['text']}")
    print(f"Labels : {example['labels']}")
    print("---")
# Out:
# Text : My favourite food is anything I didn't have to cook myself.
# Labels : [27]
# ---
# Text : Now if he does off himself, everyone will think hes having a laugh screwing with people instead of actually dead
# Labels : [27]
# ---
# Text : WHY THE FUCK IS BAYLESS ISOING
# Labels : [2]
# ---
# Text : To make her feel threatened
# Labels : [14]
# ---
# Text : Dirty Southern Wankers
# Labels : [3]
# ---

# %%
from datasets import load_dataset

dataset = load_dataset("google-research-datasets/go_emotions","simplified")

print(dataset["train"].features)
# Out:
# {'text': Value('string'), 'labels': List(ClassLabel(names=['admiration', 'amusement', 'anger', 'annoyance', 'approval', 'caring', 'confusion', 'curiosity', 'desire', 'disappointment', 'disapproval', 'disgust', 'embarrassment', 'excitement', 'fear', 'gratitude', 'grief', 'joy', 'love', 'nervousness', 'optimism', 'pride', 'realization', 'relief', 'remorse', 'sadness', 'surprise', 'neutral'])), 'id': Value('string')}

# %%
label_names= dataset['train'].features['labels'].feature.names
print("All emotions categories :")
for i,name in enumerate(label_names):
    print(f"{i} : {name}")
# Out:
# All emotions categories :
# 0 : admiration
# 1 : amusement
# 2 : anger
# 3 : annoyance
# 4 : approval
# 5 : caring
# 6 : confusion
# 7 : curiosity
# 8 : desire
# 9 : disappointment
# 10 : disapproval
# 11 : disgust
# 12 : embarrassment
# 13 : excitement
# 14 : fear
# 15 : gratitude
# 16 : grief
# 17 : joy
# 18 : love
# 19 : nervousness
# 20 : optimism
# 21 : pride
# 22 : realization
# 23 : relief
# 24 : remorse
# 25 : sadness
# 26 : surprise
# 27 : neutral

# %%
example = dataset['train'][0]
text= example['text']
label_ids= example['labels']
label_words = [label_names[i]for i in label_ids]
